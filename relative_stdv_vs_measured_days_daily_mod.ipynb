# %%
# To plot the relative error on the found amplitude/frequency/phase against the days measured. 
# This is only done for 1 particular amplitude
# Question to be answered: How long do we need to measure to have an error smaller than ....

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
# %matplotlib inline

matplotlib.rc('font', size=18)                   # Use big fonts...
plt.rcParams['figure.figsize'] = (12.0, 10.0)    # ... and big plots

measured_days_array = np.array([50.,100.,150.,200.,300])

# %%
# for input amplitude 0.05%

stdv_ampl_freq_phase_50days_inputAmplitude0005A0 = np.loadtxt("rel_stdv_ampl_freq_phase_50days_inputAmplitude0005A0")
stdv_amplitude_50days_inputAmplitude0005A0 = stdv_ampl_freq_phase_50days_inputAmplitude0005A0[0]
stdv_frequency_50days_inputAmplitude0005A0 = stdv_ampl_freq_phase_50days_inputAmplitude0005A0[1]
stdv_phase_50days_inputAmplitude0005A0 = stdv_ampl_freq_phase_50days_inputAmplitude0005A0[2]

# %%
stdv_ampl_freq_phase_100days_inputAmplitude0005A0 = np.loadtxt("rel_stdv_ampl_freq_phase_100days_inputAmplitude0005A0")
stdv_amplitude_100days_inputAmplitude0005A0 = stdv_ampl_freq_phase_100days_inputAmplitude0005A0[0]
stdv_frequency_100days_inputAmplitude0005A0 = stdv_ampl_freq_phase_100days_inputAmplitude0005A0[1]
stdv_phase_100days_inputAmplitude0005A0 = stdv_ampl_freq_phase_100days_inputAmplitude0005A0[2]

# %%
stdv_ampl_freq_phase_150days_inputAmplitude0005A0 = np.loadtxt("rel_stdv_ampl_freq_phase_150days_inputAmplitude0005A0")
stdv_amplitude_150days_inputAmplitude0005A0 = stdv_ampl_freq_phase_150days_inputAmplitude0005A0[0]
stdv_frequency_150days_inputAmplitude0005A0 = stdv_ampl_freq_phase_150days_inputAmplitude0005A0[1]
stdv_phase_150days_inputAmplitude0005A0 = stdv_ampl_freq_phase_150days_inputAmplitude0005A0[2]

# %%
stdv_ampl_freq_phase_200days_inputAmplitude0005A0 = np.loadtxt("rel_stdv_ampl_freq_phase_200days_inputAmplitude0005A0")
stdv_amplitude_200days_inputAmplitude0005A0 = stdv_ampl_freq_phase_200days_inputAmplitude0005A0[0]
stdv_frequency_200days_inputAmplitude0005A0 = stdv_ampl_freq_phase_200days_inputAmplitude0005A0[1]
stdv_phase_200days_inputAmplitude0005A0 = stdv_ampl_freq_phase_200days_inputAmplitude0005A0[2]

# %%
stdv_ampl_freq_phase_300days_inputAmplitude0005A0 = np.loadtxt("rel_stdv_ampl_freq_phase_300days_inputAmplitude0005A0")
stdv_amplitude_300days_inputAmplitude0005A0 = stdv_ampl_freq_phase_300days_inputAmplitude0005A0[0]
stdv_frequency_300days_inputAmplitude0005A0 = stdv_ampl_freq_phase_300days_inputAmplitude0005A0[1]
stdv_phase_300days_inputAmplitude0005A0 = stdv_ampl_freq_phase_300days_inputAmplitude0005A0[2]

# %%
relative_stdv_amplitude_array_0005A0 = np.array([stdv_amplitude_50days_inputAmplitude0005A0, stdv_amplitude_100days_inputAmplitude0005A0, stdv_amplitude_150days_inputAmplitude0005A0, stdv_amplitude_200days_inputAmplitude0005A0, stdv_amplitude_300days_inputAmplitude0005A0])
relative_stdv_frequency_array_0005A0 = np.array([stdv_frequency_50days_inputAmplitude0005A0, stdv_frequency_100days_inputAmplitude0005A0, stdv_frequency_150days_inputAmplitude0005A0, stdv_frequency_200days_inputAmplitude0005A0, stdv_frequency_300days_inputAmplitude0005A0])
relative_stdv_phase_array_0005A0 = np.array([stdv_phase_50days_inputAmplitude0005A0, stdv_phase_100days_inputAmplitude0005A0, stdv_phase_150days_inputAmplitude0005A0, stdv_phase_200days_inputAmplitude0005A0, stdv_phase_300days_inputAmplitude0005A0])

# %%
# for input amplitude 0.1%

stdv_ampl_freq_phase_50days_inputAmplitude001A0 = np.loadtxt("rel_stdv_ampl_freq_phase_50days_inputAmplitude001A0")
stdv_amplitude_50days_inputAmplitude001A0 = stdv_ampl_freq_phase_50days_inputAmplitude001A0[0]
stdv_frequency_50days_inputAmplitude001A0 = stdv_ampl_freq_phase_50days_inputAmplitude001A0[1]
stdv_phase_50days_inputAmplitude001A0 = stdv_ampl_freq_phase_50days_inputAmplitude001A0[2]

# %%
stdv_ampl_freq_phase_100days_inputAmplitude001A0 = np.loadtxt("rel_stdv_ampl_freq_phase_100days_inputAmplitude001A0")
stdv_amplitude_100days_inputAmplitude001A0 = stdv_ampl_freq_phase_100days_inputAmplitude001A0[0]
stdv_frequency_100days_inputAmplitude001A0 = stdv_ampl_freq_phase_100days_inputAmplitude001A0[1]
stdv_phase_100days_inputAmplitude001A0 = stdv_ampl_freq_phase_100days_inputAmplitude001A0[2]

# %%
stdv_ampl_freq_phase_150days_inputAmplitude001A0 = np.loadtxt("rel_stdv_ampl_freq_phase_150days_inputAmplitude001A0")
stdv_amplitude_150days_inputAmplitude001A0 = stdv_ampl_freq_phase_150days_inputAmplitude001A0[0]
stdv_frequency_150days_inputAmplitude001A0 = stdv_ampl_freq_phase_150days_inputAmplitude001A0[1]
stdv_phase_150days_inputAmplitude001A0 = stdv_ampl_freq_phase_150days_inputAmplitude001A0[2]

# %%
stdv_ampl_freq_phase_200days_inputAmplitude001A0 = np.loadtxt("rel_stdv_ampl_freq_phase_200days_inputAmplitude001A0")
stdv_amplitude_200days_inputAmplitude001A0 = stdv_ampl_freq_phase_200days_inputAmplitude001A0[0]
stdv_frequency_200days_inputAmplitude001A0 = stdv_ampl_freq_phase_200days_inputAmplitude001A0[1]
stdv_phase_200days_inputAmplitude001A0 = stdv_ampl_freq_phase_200days_inputAmplitude001A0[2]

# %%
stdv_ampl_freq_phase_300days_inputAmplitude001A0 = np.loadtxt("rel_stdv_ampl_freq_phase_300days_inputAmplitude001A0")
stdv_amplitude_300days_inputAmplitude001A0 = stdv_ampl_freq_phase_300days_inputAmplitude001A0[0]
stdv_frequency_300days_inputAmplitude001A0 = stdv_ampl_freq_phase_300days_inputAmplitude001A0[1]
stdv_phase_300days_inputAmplitude001A0 = stdv_ampl_freq_phase_300days_inputAmplitude001A0[2]

# %%
relative_stdv_amplitude_array_001A0 = np.array([stdv_amplitude_50days_inputAmplitude001A0, stdv_amplitude_100days_inputAmplitude001A0, stdv_amplitude_150days_inputAmplitude001A0, stdv_amplitude_200days_inputAmplitude001A0, stdv_amplitude_300days_inputAmplitude001A0])
relative_stdv_frequency_array_001A0 = np.array([stdv_frequency_50days_inputAmplitude001A0, stdv_frequency_100days_inputAmplitude001A0, stdv_frequency_150days_inputAmplitude001A0, stdv_frequency_200days_inputAmplitude001A0, stdv_frequency_300days_inputAmplitude001A0])
relative_stdv_phase_array_001A0 = np.array([stdv_phase_50days_inputAmplitude001A0, stdv_phase_100days_inputAmplitude001A0, stdv_phase_150days_inputAmplitude001A0, stdv_phase_200days_inputAmplitude001A0, stdv_phase_300days_inputAmplitude001A0])

# %%
# for input amplitude 0.2%

stdv_ampl_freq_phase_50days_inputAmplitude002A0 = np.loadtxt("rel_stdv_ampl_freq_phase_50days_inputAmplitude002A0")
stdv_amplitude_50days_inputAmplitude002A0 = stdv_ampl_freq_phase_50days_inputAmplitude002A0[0]
stdv_frequency_50days_inputAmplitude002A0 = stdv_ampl_freq_phase_50days_inputAmplitude002A0[1]
stdv_phase_50days_inputAmplitude002A0 = stdv_ampl_freq_phase_50days_inputAmplitude002A0[2]

# %%
stdv_ampl_freq_phase_100days_inputAmplitude002A0 = np.loadtxt("rel_stdv_ampl_freq_phase_100days_inputAmplitude002A0")
stdv_amplitude_100days_inputAmplitude002A0 = stdv_ampl_freq_phase_100days_inputAmplitude002A0[0]
stdv_frequency_100days_inputAmplitude002A0 = stdv_ampl_freq_phase_100days_inputAmplitude002A0[1]
stdv_phase_100days_inputAmplitude002A0 = stdv_ampl_freq_phase_100days_inputAmplitude002A0[2]

# %%
stdv_ampl_freq_phase_150days_inputAmplitude002A0 = np.loadtxt("rel_stdv_ampl_freq_phase_150days_inputAmplitude002A0")
stdv_amplitude_150days_inputAmplitude002A0 = stdv_ampl_freq_phase_150days_inputAmplitude002A0[0]
stdv_frequency_150days_inputAmplitude002A0 = stdv_ampl_freq_phase_150days_inputAmplitude002A0[1]
stdv_phase_150days_inputAmplitude002A0 = stdv_ampl_freq_phase_150days_inputAmplitude002A0[2]

# %%
stdv_ampl_freq_phase_200days_inputAmplitude002A0 = np.loadtxt("rel_stdv_ampl_freq_phase_200days_inputAmplitude002A0")
stdv_amplitude_200days_inputAmplitude002A0 = stdv_ampl_freq_phase_200days_inputAmplitude002A0[0]
stdv_frequency_200days_inputAmplitude002A0 = stdv_ampl_freq_phase_200days_inputAmplitude002A0[1]
stdv_phase_200days_inputAmplitude002A0 = stdv_ampl_freq_phase_200days_inputAmplitude002A0[2]

# %%
stdv_ampl_freq_phase_300days_inputAmplitude002A0 = np.loadtxt("rel_stdv_ampl_freq_phase_300days_inputAmplitude002A0")
stdv_amplitude_300days_inputAmplitude002A0 = stdv_ampl_freq_phase_300days_inputAmplitude002A0[0]
stdv_frequency_300days_inputAmplitude002A0 = stdv_ampl_freq_phase_300days_inputAmplitude002A0[1]
stdv_phase_300days_inputAmplitude002A0 = stdv_ampl_freq_phase_300days_inputAmplitude002A0[2]

# %%
relative_stdv_amplitude_array_002A0 = np.array([stdv_amplitude_50days_inputAmplitude002A0, stdv_amplitude_100days_inputAmplitude002A0, stdv_amplitude_150days_inputAmplitude002A0, stdv_amplitude_200days_inputAmplitude002A0, stdv_amplitude_300days_inputAmplitude002A0])
relative_stdv_frequency_array_002A0 = np.array([stdv_frequency_50days_inputAmplitude002A0, stdv_frequency_100days_inputAmplitude002A0, stdv_frequency_150days_inputAmplitude002A0, stdv_frequency_200days_inputAmplitude002A0, stdv_frequency_300days_inputAmplitude002A0])
relative_stdv_phase_array_002A0 = np.array([stdv_phase_50days_inputAmplitude002A0, stdv_phase_100days_inputAmplitude002A0, stdv_phase_150days_inputAmplitude002A0, stdv_phase_200days_inputAmplitude002A0, stdv_phase_300days_inputAmplitude002A0])

# %%
plt.title('Input Amplitude = 0.05%', fontsize = 28)

plt.plot(measured_days_array,relative_stdv_amplitude_array_0005A0, 'r', linewidth=2., label="relative stdv amplitude")
plt.plot(measured_days_array,relative_stdv_amplitude_array_0005A0, 'ro')
plt.plot(measured_days_array,relative_stdv_phase_array_0005A0, 'b', linewidth=2., label="relative stdv phase")
plt.plot(measured_days_array,relative_stdv_phase_array_0005A0, 'bo')
plt.plot(measured_days_array,relative_stdv_frequency_array_0005A0, 'g', linewidth=2., label="relative stdv frequency")
plt.plot(measured_days_array,relative_stdv_frequency_array_0005A0, 'go')
plt.xlabel('measured days [days]', fontsize = 28)
#plt.xlim(0, 300)
plt.ylabel('relative standard deviation [%]', fontsize = 28)
#plt.ylim(0., 0.09)
plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
# plt.savefig("rel_error_vs_measured_days_005percent.pdf", format='pdf', dpi=300)
plt.savefig("rel_err_vs_measured_days_005percentPNG.png", format='png', dpi=300)
plt.show()

# %%
plt.title('Input Amplitude = 0.1%', fontsize = 28)

plt.plot(measured_days_array,relative_stdv_amplitude_array_001A0, 'r', linewidth=2., label="relative stdv amplitude")
plt.plot(measured_days_array,relative_stdv_amplitude_array_001A0, 'ro')
plt.plot(measured_days_array,relative_stdv_phase_array_001A0, 'b', linewidth=2., label="relative stdv phase")
plt.plot(measured_days_array,relative_stdv_phase_array_001A0, 'bo')
plt.plot(measured_days_array,relative_stdv_frequency_array_001A0, 'g', linewidth=2., label="relative stdv frequency")
plt.plot(measured_days_array,relative_stdv_frequency_array_001A0, 'go')
plt.xlabel('measured days [days]', fontsize = 28)
#plt.xlim(0, 300)
plt.ylabel('relative standard deviation [%]', fontsize = 28)
#plt.ylim(0., 0.09)
#plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
#plt.savefig("rel_error_vs_measured_days_01percent.pdf", format='pdf', dpi=300)
plt.savefig("rel_err_vs_measured_days_01percentPNG.png", format='png', dpi=300)
plt.show()

# %%
plt.title('Input Amplitude = 0.2%')

plt.plot(measured_days_array,relative_stdv_amplitude_array_002A0, 'r', linewidth=2., label="relative stdv amplitude")
plt.plot(measured_days_array,relative_stdv_amplitude_array_002A0, 'ro')
plt.plot(measured_days_array,relative_stdv_phase_array_002A0, 'b', linewidth=2., label="relative stdv phase")
plt.plot(measured_days_array,relative_stdv_phase_array_002A0, 'bo')
plt.plot(measured_days_array,relative_stdv_frequency_array_002A0, 'g', linewidth=2., label="relative stdv frequency")
plt.plot(measured_days_array,relative_stdv_frequency_array_002A0, 'go')
plt.xlabel('measured days [days]')
#plt.xlim(0, 300)
plt.ylabel('relative standard deviation [%]')
#plt.ylim(0., 0.09)
#plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
plt.savefig("rel_error_vs_measured_days_02percent.pdf", format='pdf', dpi=300)
plt.show()
