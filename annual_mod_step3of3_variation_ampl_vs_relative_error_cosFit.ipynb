# %%
# Plot variation in amplitude vs relative/percent error in amplitude/phase/frequency 
# using mean_found_amplitude/phase/frequency_array, stdv_found_amplitude/phase/frequency_array 
# from Sim_radioactive_decay_NO24h_FFT_loop_varying_amplitude

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import math
from numpy import *
# %matplotlib inline

matplotlib.rc('font', size=18)                   # Use big fonts...
plt.rcParams['figure.figsize'] = (12.0, 10.0)    # ... and big plots

A0 = 37 

# Varying amplitude in percentages.

# input_amplitude_array_annual_mod_005_01 = np.loadtxt("annual_mod_input_amplitude_CosFit_005_01")
# amplitude_percentage_annual_mod_005_01 = 100*input_amplitude_array_annual_mod_005_01/A0

annual_mod_input_amplitude_CosFit = np.loadtxt("annual_mod_input_amplitude_CosFit_V3")
amplitude_percentage_annual_mod = 100*annual_mod_input_amplitude_CosFit/A0

#for 0.00-0.01 amplitude in steps of 0.0001
annual_mod_input_amplitude_CosFit1 = np.loadtxt("annual_mod_input_amplitude_CosFit_0.00_0.005_st0.0001")
annual_mod_input_amplitude_CosFit2 = np.loadtxt("annual_mod_input_amplitude_CosFit_0.005_0.01_st0.0001")
annual_mod_input_amplitude_CosFitLong = np.hstack((annual_mod_input_amplitude_CosFit1,annual_mod_input_amplitude_CosFit2))
amplitude_percentage_annual_modLong = 100*annual_mod_input_amplitude_CosFitLong/A0

# %%
# Cosine Fit 300 days run:
relative_error_found_amplitude_annual_mod_300_CosFit = np.loadtxt("relative_error_found_amplitude_annual_mod_300_CosFit")
relative_error_found_frequency_annual_mod_300_CosFit = np.loadtxt("relative_error_found_frequency_annual_mod_300_CosFit")
relative_error_found_phase_annual_mod_300_CosFit = np.loadtxt("relative_error_found_phase_annual_mod_300_CosFit")

# %%
mean_found_amplitude_CosFit_annual_mod_300 = np.loadtxt("mean_found_amplitude_CosFit_annual_mod_300")
stdv_found_amplitude_CosFit_annual_mod_300 = np.loadtxt("stdv_found_amplitude_CosFit_annual_mod_300")
mean_found_frequency_CosFit_annual_mod_300 = np.loadtxt("mean_found_frequency_CosFit_annual_mod_300")
stdv_found_frequency_CosFit_annual_mod_300 = np.loadtxt("stdv_found_frequency_CosFit_annual_mod_300")
mean_found_phase_CosFit_annual_mod_300 = np.loadtxt("mean_found_phase_CosFit_annual_mod_300")
stdv_found_phase_CosFit_annual_mod_300 = np.loadtxt("stdv_found_phase_CosFit_annual_mod_300")

# %%
# Cosine Fit 400 days run:
relative_error_found_amplitude_annual_mod_400_CosFit = np.loadtxt("relative_error_found_amplitude_annual_mod_400_CosFit")
relative_error_found_frequency_annual_mod_400_CosFit = np.loadtxt("relative_error_found_frequency_annual_mod_400_CosFit")
relative_error_found_phase_annual_mod_400_CosFit = np.loadtxt("relative_error_found_phase_annual_mod_400_CosFit")

# %%
mean_found_amplitude_CosFit_annual_mod_400 = np.loadtxt("mean_found_amplitude_CosFit_annual_mod_400")
stdv_found_amplitude_CosFit_annual_mod_400 = np.loadtxt("stdv_found_amplitude_CosFit_annual_mod_400")
mean_found_frequency_CosFit_annual_mod_400 = np.loadtxt("mean_found_frequency_CosFit_annual_mod_400")
stdv_found_frequency_CosFit_annual_mod_400 = np.loadtxt("stdv_found_frequency_CosFit_annual_mod_400")
mean_found_phase_CosFit_annual_mod_400 = np.loadtxt("mean_found_phase_CosFit_annual_mod_400")
stdv_found_phase_CosFit_annual_mod_400 = np.loadtxt("stdv_found_phase_CosFit_annual_mod_400")

# %%
# Cosine Fit 500 days run:
relative_error_found_amplitude_annual_mod_500_CosFit = np.loadtxt("relative_error_found_amplitude_annual_mod_500_CosFit")
relative_error_found_frequency_annual_mod_500_CosFit = np.loadtxt("relative_error_found_frequency_annual_mod_500_CosFit")
relative_error_found_phase_annual_mod_500_CosFit = np.loadtxt("relative_error_found_phase_annual_mod_500_CosFit")

# %%
mean_found_amplitude_CosFit_annual_mod_500 = np.loadtxt("mean_found_amplitude_CosFit_annual_mod_500")
stdv_found_amplitude_CosFit_annual_mod_500 = np.loadtxt("stdv_found_amplitude_CosFit_annual_mod_500")
mean_found_frequency_CosFit_annual_mod_500 = np.loadtxt("mean_found_frequency_CosFit_annual_mod_500")
stdv_found_frequency_CosFit_annual_mod_500 = np.loadtxt("stdv_found_frequency_CosFit_annual_mod_500")
mean_found_phase_CosFit_annual_mod_500 = np.loadtxt("mean_found_phase_CosFit_annual_mod_500")
stdv_found_phase_CosFit_annual_mod_500 = np.loadtxt("stdv_found_phase_CosFit_annual_mod_500")

# %%
# Cosine Fit 600 days run:
relative_error_found_amplitude_annual_mod_600_CosFit = np.loadtxt("relative_error_found_amplitude_annual_mod_600_CosFit")
relative_error_found_frequency_annual_mod_600_CosFit = np.loadtxt("relative_error_found_frequency_annual_mod_600_CosFit")
relative_error_found_phase_annual_mod_600_CosFit = np.loadtxt("relative_error_found_phase_annual_mod_600_CosFit")

# %%
mean_found_amplitude_CosFit_annual_mod_600 = np.loadtxt("mean_found_amplitude_CosFit_annual_mod_600")
stdv_found_amplitude_CosFit_annual_mod_600 = np.loadtxt("stdv_found_amplitude_CosFit_annual_mod_600")
mean_found_frequency_CosFit_annual_mod_600 = np.loadtxt("mean_found_frequency_CosFit_annual_mod_600")
stdv_found_frequency_CosFit_annual_mod_600 = np.loadtxt("stdv_found_frequency_CosFit_annual_mod_600")
mean_found_phase_CosFit_annual_mod_600 = np.loadtxt("mean_found_phase_CosFit_annual_mod_600")
stdv_found_phase_CosFit_annual_mod_600 = np.loadtxt("stdv_found_phase_CosFit_annual_mod_600")

# %%
# Cosine Fit 750 days run:
relative_error_found_amplitude_annual_mod_750_CosFit = np.loadtxt("relative_error_found_amplitude_annual_mod_750_CosFit")
relative_error_found_frequency_annual_mod_750_CosFit = np.loadtxt("relative_error_found_frequency_annual_mod_750_CosFit")
relative_error_found_phase_annual_mod_750_CosFit = np.loadtxt("relative_error_found_phase_annual_mod_750_CosFit")

# %%
mean_found_amplitude_CosFit_annual_mod_750 = np.loadtxt("mean_found_amplitude_CosFit_annual_mod_750")
stdv_found_amplitude_CosFit_annual_mod_750 = np.loadtxt("stdv_found_amplitude_CosFit_annual_mod_750")
mean_found_frequency_CosFit_annual_mod_750 = np.loadtxt("mean_found_frequency_CosFit_annual_mod_750")
stdv_found_frequency_CosFit_annual_mod_750 = np.loadtxt("stdv_found_frequency_CosFit_annual_mod_750")
mean_found_phase_CosFit_annual_mod_750 = np.loadtxt("mean_found_phase_CosFit_annual_mod_750")
stdv_found_phase_CosFit_annual_mod_750 = np.loadtxt("stdv_found_phase_CosFit_annual_mod_750")

# %%
figAmpl = plt.figure()
#plt.title('Sensitivity research with input value - Amplitude - annual mod - Cos Fit', fontsize=25)

# Cosine fit:
plt.errorbar(annual_mod_input_amplitude_CosFitLong, mean_found_amplitude_CosFit_annual_mod_300, stdv_found_amplitude_CosFit_annual_mod_300, label="Found amplitude with errors - 300 days")
#plt.errorbar(annual_mod_input_amplitude_CosFit, mean_found_amplitude_CosFit_annual_mod_400[5:100], stdv_found_amplitude_CosFit_annual_mod_400[5:100], label="Found amplitude with errors - 400 days")
plt.errorbar(annual_mod_input_amplitude_CosFitLong, mean_found_amplitude_CosFit_annual_mod_400, stdv_found_amplitude_CosFit_annual_mod_400, label="Found amplitude with errors - 400 days")
plt.errorbar(annual_mod_input_amplitude_CosFitLong, mean_found_amplitude_CosFit_annual_mod_500, stdv_found_amplitude_CosFit_annual_mod_500, label="Found amplitude with errors - 500 days")
plt.errorbar(annual_mod_input_amplitude_CosFitLong, mean_found_amplitude_CosFit_annual_mod_600, stdv_found_amplitude_CosFit_annual_mod_600, label="Found amplitude with errors - 600 days")
plt.errorbar(annual_mod_input_amplitude_CosFitLong, mean_found_amplitude_CosFit_annual_mod_750, stdv_found_amplitude_CosFit_annual_mod_750, label="Found amplitude with errors - 750 days")

plt.plot(annual_mod_input_amplitude_CosFitLong, annual_mod_input_amplitude_CosFitLong, 'k', linewidth=4., label="Input amplitude")
plt.xlabel('input amplitude[Hz]', fontsize = 28)
plt.xlim(0.00, max(annual_mod_input_amplitude_CosFit))
#plt.xscale('log')
plt.ylabel('found amplitude [Hz]', fontsize = 28)
plt.ylim(-0.005, .4)
plt.legend(loc=2, borderaxespad=0.)
# plt.savefig('input_yearly_found_with_errors_amplitude.pdf', format='pdf', dpi=figAmpl.dpi)
plt.savefig('input_yearly_found_with_err_amplitudePNG.png', format='png', dpi=figAmpl.dpi)
plt.show()

# %%
figFreq = plt.figure()
#plt.title('                          Sensitivity research with input value - Frequency- 300 runs', fontsize=25)

frequency_input = 1./(365.25*24*60*60.0)
input_frequency_array = np.ones(len(annual_mod_input_amplitude_CosFitLong))*frequency_input

plt.errorbar(amplitude_percentage_annual_modLong, mean_found_frequency_CosFit_annual_mod_300, stdv_found_frequency_CosFit_annual_mod_300, label="Found frequency with errors - 300 days")
plt.errorbar(amplitude_percentage_annual_modLong, mean_found_frequency_CosFit_annual_mod_400, stdv_found_frequency_CosFit_annual_mod_400, label="Found frequency with errors - 400 days")
#plt.errorbar(amplitude_percentage_annual_mod, mean_found_frequency_CosFit_annual_mod_400_V3, stdv_found_frequency_CosFit_annual_mod_400_V3, label="Found frequency with errors - 400 days V3")
plt.errorbar(amplitude_percentage_annual_modLong, mean_found_frequency_CosFit_annual_mod_500, stdv_found_frequency_CosFit_annual_mod_500, label="Found frequency with errors - 500 days")
plt.errorbar(amplitude_percentage_annual_modLong, mean_found_frequency_CosFit_annual_mod_600, stdv_found_frequency_CosFit_annual_mod_600, label="Found frequency with errors - 600 days")
plt.errorbar(amplitude_percentage_annual_modLong, mean_found_frequency_CosFit_annual_mod_750, stdv_found_frequency_CosFit_annual_mod_750, label="Found frequency with errors - 750 days")

plt.plot(amplitude_percentage_annual_modLong, input_frequency_array, 'k', linewidth=4., label="Input frequency")
plt.xlabel('input amplitude[%]', fontsize = 28)
#plt.xlim(0.000005*A0/100, 0.2)
#plt.yscale('log')
plt.ylabel('found freqeuncy [Hz]', fontsize = 28)
plt.ylim(2.7*10**(-8), 3.5*10**(-8))
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
#plt.savefig("input_yearly_found_with_errors_frequency.pdf", format='pdf', dpi = figFreq.dpi) 
plt.savefig("input_yearly_found_with_err_frequencyPNG.png", format='png', dpi = 300) 
plt.show()

# %%
figPhase = plt.figure()
#plt.title('Sensitivity research with input value - Phase - annual mod - Cos Fit - 300 runs')

phase_in_Degrees = 40.
phase_input = np.deg2rad(phase_in_Degrees)
input_phase_array = np.ones(len(annual_mod_input_amplitude_CosFitLong))*phase_input

plt.errorbar(amplitude_percentage_annual_modLong, mean_found_phase_CosFit_annual_mod_300, stdv_found_phase_CosFit_annual_mod_300, label="Found phase with errors - 300 days")
plt.errorbar(amplitude_percentage_annual_modLong, mean_found_phase_CosFit_annual_mod_400, stdv_found_phase_CosFit_annual_mod_400, label="Found phase with errors - 400 days")
plt.errorbar(amplitude_percentage_annual_modLong, mean_found_phase_CosFit_annual_mod_500, stdv_found_phase_CosFit_annual_mod_500, label="Found phase with errors - 500 days")
plt.errorbar(amplitude_percentage_annual_modLong, mean_found_phase_CosFit_annual_mod_600, stdv_found_phase_CosFit_annual_mod_600, label="Found phase with errors - 600 days")
plt.errorbar(amplitude_percentage_annual_modLong, mean_found_phase_CosFit_annual_mod_750, stdv_found_phase_CosFit_annual_mod_750, label="Found phase with errors - 750 days")

plt.plot(amplitude_percentage_annual_modLong, input_phase_array, 'k', linewidth=3., label="Input phase")
plt.xlabel('input amplitude[%]')
#plt.xlim(0.000005*A0/100, (0.2))
#plt.xlim(0.1, (0.2))
plt.ylabel('found phase')
plt.ylim(-.05, 4.)
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
plt.savefig("input_yearly_found_with_errors_phase.pdf", format ='pdf', dpi = figPhase.dpi) 
plt.show()

# %%
# Plot Sensitivity research - Amplitude - 24h for amplitude is 0.01-1.9%

plt.title('Sensitivity research - Amplitude - 300 runs')
plt.plot(amplitude_percentage_annual_mod, relative_error_found_amplitude_annual_mod_300_CosFit, label="RSD in found amplitude - 300 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_amplitude_annual_mod_400_CosFit, label="RSD in found amplitude - 400 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_amplitude_annual_mod_500_CosFit, label="RSD in found amplitude - 500 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_amplitude_annual_mod_600_CosFit, label="RSD in found amplitude - 600 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_amplitude_annual_mod_750_CosFit, label="RSD in found amplitude - 750 days")

plt.xlabel('amplitude[%]')
#plt.xlim(min(amplitude_percentage_annual_mod_005_01), max(amplitude_percentage_annual_mod_005_01))
#plt.xscale('log')
plt.ylim(-0.5, 19.9)
plt.ylabel('relative standard deviation (RSD) [%]')
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
plt.savefig("yearly_RSD_amplitude.png") 
plt.show()
print("Half life time: 5.27 years, frequency input = 1./(365.25*24*60*60.0) = 1 modulation per year and phase input = 40 degrees")
print("amplitude input = percentage*A0 and RSD = (standard_deviation_found_ampl/freq/phase_array)/(mean_found_ampl/freq/phase_array)")
# Out:
# Half life time: 5.27 years, frequency input = 1./(365.25*24*60*60.0) = 1 modulation per year and phase input = 40 degrees
# amplitude input = percentage*A0 and RSD = (standard_deviation_found_ampl/freq/phase_array)/(mean_found_ampl/freq/phase_array)

# %%
# Plot Sensitivity research - Phase for amplitude is 0.01-1.9%

plt.title('Sensitivity research - Phase - 300 runs')
plt.plot(amplitude_percentage_annual_mod, relative_error_found_phase_annual_mod_300_CosFit, label="RSD in found phase - 300 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_phase_annual_mod_400_CosFit, label="RSD in found phase - 400 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_phase_annual_mod_500_CosFit, label="RSD in found phase - 500 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_phase_annual_mod_600_CosFit, label="RSD in found phase - 600 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_phase_annual_mod_750_CosFit, label="RSD in found phase - 750 days")

plt.xlabel('amplitude[%]')
#plt.yscale('log')
#plt.xscale('log')
plt.xlim(min(amplitude_percentage_annual_mod), max(amplitude_percentage_annual_mod))
plt.ylim(0.,50.)
plt.ylabel('relative standard deviation (RSD)[%]')
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
plt.savefig("yearly_RSD_phase.png") 
plt.show()

# %%
# Plot Sensitivity research - Frequency for amplitude is 0.01-1.9%

plt.title('       Sensitivity research - Frequency - 300 runs')
plt.plot(amplitude_percentage_annual_mod, relative_error_found_frequency_annual_mod_300_CosFit, label="RSD in found frequency - 300 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_frequency_annual_mod_400_CosFit, label="RSD in found frequency - 400 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_frequency_annual_mod_500_CosFit, label="RSD in found frequency - 500 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_frequency_annual_mod_600_CosFit, label="RSD in found frequency - 600 days")
plt.plot(amplitude_percentage_annual_mod, relative_error_found_frequency_annual_mod_750_CosFit, label="RSD in found frequency - 750 days")

plt.xlabel('amplitude[%]')
#plt.xlim(min(amplitude_percentage_annual_mod), max(amplitude_percentage_annual_mod))
plt.ylim(0.,15.)
plt.ylabel('relative standard deviation (RSD)[%]')
#plt.yscale('log')
# plt.xscale('log')
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
plt.savefig("yearly_RSD_frequency.png") 
plt.show()
