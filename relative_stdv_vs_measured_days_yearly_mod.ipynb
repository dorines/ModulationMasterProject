# %%
# To plot the relative error on the found amplitude/frequency/phase against the days measured. 
# This is only done for 1 particular amplitude
# Question to be answered: How long do we need to measure to have an error smaller than ....

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
# %matplotlib inline

matplotlib.rc('font', size=18)                   # Use big fonts...
plt.rcParams['figure.figsize'] = (12.0, 10.0)    # ... and big plots

measured_days_array = np.array([300.,400.,500.,600.,750])

# %%
# for input amplitude 0.05%

stdv_amplitude_300days_inputAmplitude0005A0 = np.loadtxt("stdv_ampl_300days_yearly_inputAmplitude0005A0")
stdv_frequency_300days_inputAmplitude0005A0 = np.loadtxt("stdv_freq_300days_yearly_inputAmplitude0005A0")
stdv_phase_300days_inputAmplitude0005A0 = np.loadtxt("stdv_phase_300days_yearly_inputAmplitude0005A0")

mean_amplitude_300days_inputAmplitude0005A0 = np.loadtxt("mean_ampl_300days_yearly_inputAmplitude0005A0")
mean_frequency_300days_inputAmplitude0005A0 = np.loadtxt("mean_freq_300days_yearly_inputAmplitude0005A0")
mean_phase_300days_inputAmplitude0005A0 = np.loadtxt("mean_phase_300days_yearly_inputAmplitude0005A0")

relative_error_found_amplitude_annual_mod_300_CosFit_A0005 = 100*stdv_amplitude_300days_inputAmplitude0005A0/mean_amplitude_300days_inputAmplitude0005A0
relative_error_found_frequency_annual_mod_300_CosFit_A0005 = 100*stdv_frequency_300days_inputAmplitude0005A0/mean_frequency_300days_inputAmplitude0005A0
relative_error_found_phase_annual_mod_300_CosFit_A0005 = 100*stdv_phase_300days_inputAmplitude0005A0/mean_phase_300days_inputAmplitude0005A0

# %%
stdv_amplitude_400days_inputAmplitude0005A0 = np.loadtxt("stdv_ampl_400days_yearly_inputAmplitude0005A0")
stdv_frequency_400days_inputAmplitude0005A0 = np.loadtxt("stdv_freq_400days_yearly_inputAmplitude0005A0")
stdv_phase_400days_inputAmplitude0005A0 = np.loadtxt("stdv_phase_400days_yearly_inputAmplitude0005A0")

mean_amplitude_400days_inputAmplitude0005A0 = np.loadtxt("mean_ampl_400days_yearly_inputAmplitude0005A0")
mean_frequency_400days_inputAmplitude0005A0 = np.loadtxt("mean_freq_400days_yearly_inputAmplitude0005A0")
mean_phase_400days_inputAmplitude0005A0 = np.loadtxt("mean_phase_400days_yearly_inputAmplitude0005A0")

relative_error_found_amplitude_annual_mod_400_CosFit_A0005 = 100*stdv_amplitude_400days_inputAmplitude0005A0/mean_amplitude_400days_inputAmplitude0005A0
relative_error_found_frequency_annual_mod_400_CosFit_A0005 = 100*stdv_frequency_400days_inputAmplitude0005A0/mean_frequency_400days_inputAmplitude0005A0
relative_error_found_phase_annual_mod_400_CosFit_A0005 = 100*stdv_phase_400days_inputAmplitude0005A0/mean_phase_400days_inputAmplitude0005A0

# %%
stdv_amplitude_500days_inputAmplitude0005A0 = np.loadtxt("stdv_ampl_500days_yearly_inputAmplitude0005A0")
stdv_frequency_500days_inputAmplitude0005A0 = np.loadtxt("stdv_freq_500days_yearly_inputAmplitude0005A0")
stdv_phase_500days_inputAmplitude0005A0 = np.loadtxt("stdv_phase_500days_yearly_inputAmplitude0005A0")

mean_amplitude_500days_inputAmplitude0005A0 = np.loadtxt("mean_ampl_500days_yearly_inputAmplitude0005A0")
mean_frequency_500days_inputAmplitude0005A0 = np.loadtxt("mean_freq_500days_yearly_inputAmplitude0005A0")
mean_phase_500days_inputAmplitude0005A0 = np.loadtxt("mean_phase_500days_yearly_inputAmplitude0005A0")

relative_error_found_amplitude_annual_mod_500_CosFit_A0005 = 100*stdv_amplitude_500days_inputAmplitude0005A0/mean_amplitude_500days_inputAmplitude0005A0
relative_error_found_frequency_annual_mod_500_CosFit_A0005 = 100*stdv_frequency_500days_inputAmplitude0005A0/mean_frequency_500days_inputAmplitude0005A0
relative_error_found_phase_annual_mod_500_CosFit_A0005 = 100*stdv_phase_500days_inputAmplitude0005A0/mean_phase_500days_inputAmplitude0005A0

# %%
stdv_amplitude_600days_inputAmplitude0005A0 = np.loadtxt("stdv_ampl_600days_yearly_inputAmplitude0005A0")
stdv_frequency_600days_inputAmplitude0005A0 = np.loadtxt("stdv_freq_600days_yearly_inputAmplitude0005A0")
stdv_phase_600days_inputAmplitude0005A0 = np.loadtxt("stdv_phase_600days_yearly_inputAmplitude0005A0")

mean_amplitude_600days_inputAmplitude0005A0 = np.loadtxt("mean_ampl_600days_yearly_inputAmplitude0005A0")
mean_frequency_600days_inputAmplitude0005A0 = np.loadtxt("mean_freq_600days_yearly_inputAmplitude0005A0")
mean_phase_600days_inputAmplitude0005A0 = np.loadtxt("mean_phase_600days_yearly_inputAmplitude0005A0")

relative_error_found_amplitude_annual_mod_600_CosFit_A0005 = 100*stdv_amplitude_600days_inputAmplitude0005A0/mean_amplitude_600days_inputAmplitude0005A0
relative_error_found_frequency_annual_mod_600_CosFit_A0005 = 100*stdv_frequency_600days_inputAmplitude0005A0/mean_frequency_600days_inputAmplitude0005A0
relative_error_found_phase_annual_mod_600_CosFit_A0005 = 100*stdv_phase_600days_inputAmplitude0005A0/mean_phase_600days_inputAmplitude0005A0

# %%
stdv_amplitude_750days_inputAmplitude0005A0 = np.loadtxt("stdv_ampl_750days_yearly_inputAmplitude0005A0")
stdv_frequency_750days_inputAmplitude0005A0 = np.loadtxt("stdv_freq_750days_yearly_inputAmplitude0005A0")
stdv_phase_750days_inputAmplitude0005A0 = np.loadtxt("stdv_phase_750days_yearly_inputAmplitude0005A0")

mean_amplitude_750days_inputAmplitude0005A0 = np.loadtxt("mean_ampl_750days_yearly_inputAmplitude0005A0")
mean_frequency_750days_inputAmplitude0005A0 = np.loadtxt("mean_freq_750days_yearly_inputAmplitude0005A0")
mean_phase_750days_inputAmplitude0005A0 = np.loadtxt("mean_phase_750days_yearly_inputAmplitude0005A0")

relative_error_found_amplitude_annual_mod_750_CosFit_A0005 = 100*stdv_amplitude_750days_inputAmplitude0005A0/mean_amplitude_750days_inputAmplitude0005A0
relative_error_found_frequency_annual_mod_750_CosFit_A0005 = 100*stdv_frequency_750days_inputAmplitude0005A0/mean_frequency_750days_inputAmplitude0005A0
relative_error_found_phase_annual_mod_750_CosFit_A0005 = 100*stdv_phase_750days_inputAmplitude0005A0/mean_phase_750days_inputAmplitude0005A0

# %%
relative_stdv_amplitude_array_0005A0_anMod = np.hstack((relative_error_found_amplitude_annual_mod_300_CosFit_A0005, relative_error_found_amplitude_annual_mod_400_CosFit_A0005, relative_error_found_amplitude_annual_mod_500_CosFit_A0005, relative_error_found_amplitude_annual_mod_600_CosFit_A0005, relative_error_found_amplitude_annual_mod_750_CosFit_A0005))
relative_stdv_frequency_array_0005A0_anMod = np.hstack((relative_error_found_frequency_annual_mod_300_CosFit_A0005, relative_error_found_frequency_annual_mod_400_CosFit_A0005, relative_error_found_frequency_annual_mod_500_CosFit_A0005, relative_error_found_frequency_annual_mod_600_CosFit_A0005, relative_error_found_frequency_annual_mod_750_CosFit_A0005))
relative_stdv_phase_array_0005A0_anMod = np.hstack((relative_error_found_phase_annual_mod_300_CosFit_A0005, relative_error_found_phase_annual_mod_400_CosFit_A0005, relative_error_found_phase_annual_mod_500_CosFit_A0005, relative_error_found_phase_annual_mod_600_CosFit_A0005, relative_error_found_phase_annual_mod_750_CosFit_A0005))

# %%
# for input amplitude 0.1%

stdv_amplitude_300days_inputAmplitude001A0 = np.loadtxt("stdv_ampl_300days_yearly_inputAmplitude001A0")
stdv_frequency_300days_inputAmplitude001A0 = np.loadtxt("stdv_freq_300days_yearly_inputAmplitude001A0")
stdv_phase_300days_inputAmplitude001A0 = np.loadtxt("stdv_phase_300days_yearly_inputAmplitude001A0")

mean_amplitude_300days_inputAmplitude001A0 = np.loadtxt("mean_ampl_300days_yearly_inputAmplitude001A0")
mean_frequency_300days_inputAmplitude001A0 = np.loadtxt("mean_freq_300days_yearly_inputAmplitude001A0")
mean_phase_300days_inputAmplitude001A0 = np.loadtxt("mean_phase_300days_yearly_inputAmplitude001A0")

relative_error_found_amplitude_annual_mod_300_CosFit_A001 = 100*stdv_amplitude_300days_inputAmplitude001A0/mean_amplitude_300days_inputAmplitude001A0
relative_error_found_frequency_annual_mod_300_CosFit_A001 = 100*stdv_frequency_300days_inputAmplitude001A0/mean_frequency_300days_inputAmplitude001A0
relative_error_found_phase_annual_mod_300_CosFit_A001 = 100*stdv_phase_300days_inputAmplitude001A0/mean_phase_300days_inputAmplitude001A0

# %%
stdv_amplitude_400days_inputAmplitude001A0 = np.loadtxt("stdv_ampl_400days_yearly_inputAmplitude001A0")
stdv_frequency_400days_inputAmplitude001A0 = np.loadtxt("stdv_freq_400days_yearly_inputAmplitude001A0")
stdv_phase_400days_inputAmplitude001A0 = np.loadtxt("stdv_phase_400days_yearly_inputAmplitude001A0")

mean_amplitude_400days_inputAmplitude001A0 = np.loadtxt("mean_ampl_400days_yearly_inputAmplitude001A0")
mean_frequency_400days_inputAmplitude001A0 = np.loadtxt("mean_freq_400days_yearly_inputAmplitude001A0")
mean_phase_400days_inputAmplitude001A0 = np.loadtxt("mean_phase_400days_yearly_inputAmplitude001A0")

relative_error_found_amplitude_annual_mod_400_CosFit_A001 = 100*stdv_amplitude_400days_inputAmplitude001A0/mean_amplitude_400days_inputAmplitude001A0
relative_error_found_frequency_annual_mod_400_CosFit_A001 = 100*stdv_frequency_400days_inputAmplitude001A0/mean_frequency_400days_inputAmplitude001A0
relative_error_found_phase_annual_mod_400_CosFit_A001 = 100*stdv_phase_400days_inputAmplitude001A0/mean_phase_400days_inputAmplitude001A0

# %%
stdv_amplitude_500days_inputAmplitude001A0 = np.loadtxt("stdv_ampl_500days_yearly_inputAmplitude001A0")
stdv_frequency_500days_inputAmplitude001A0 = np.loadtxt("stdv_freq_500days_yearly_inputAmplitude001A0")
stdv_phase_500days_inputAmplitude001A0 = np.loadtxt("stdv_phase_500days_yearly_inputAmplitude001A0")

mean_amplitude_500days_inputAmplitude001A0 = np.loadtxt("mean_ampl_500days_yearly_inputAmplitude001A0")
mean_frequency_500days_inputAmplitude001A0 = np.loadtxt("mean_freq_500days_yearly_inputAmplitude001A0")
mean_phase_500days_inputAmplitude001A0 = np.loadtxt("mean_phase_500days_yearly_inputAmplitude001A0")

relative_error_found_amplitude_annual_mod_500_CosFit_A001 = 100*stdv_amplitude_500days_inputAmplitude001A0/mean_amplitude_500days_inputAmplitude001A0
relative_error_found_frequency_annual_mod_500_CosFit_A001 = 100*stdv_frequency_500days_inputAmplitude001A0/mean_frequency_500days_inputAmplitude001A0
relative_error_found_phase_annual_mod_500_CosFit_A001 = 100*stdv_phase_500days_inputAmplitude001A0/mean_phase_500days_inputAmplitude001A0

# %%
stdv_amplitude_600days_inputAmplitude001A0 = np.loadtxt("stdv_ampl_600days_yearly_inputAmplitude001A0")
stdv_frequency_600days_inputAmplitude001A0 = np.loadtxt("stdv_freq_600days_yearly_inputAmplitude001A0")
stdv_phase_600days_inputAmplitude001A0 = np.loadtxt("stdv_phase_600days_yearly_inputAmplitude001A0")

mean_amplitude_600days_inputAmplitude001A0 = np.loadtxt("mean_ampl_600days_yearly_inputAmplitude001A0")
mean_frequency_600days_inputAmplitude001A0 = np.loadtxt("mean_freq_600days_yearly_inputAmplitude001A0")
mean_phase_600days_inputAmplitude001A0 = np.loadtxt("mean_phase_600days_yearly_inputAmplitude001A0")

relative_error_found_amplitude_annual_mod_600_CosFit_A001 = 100*stdv_amplitude_600days_inputAmplitude001A0/mean_amplitude_600days_inputAmplitude001A0
relative_error_found_frequency_annual_mod_600_CosFit_A001 = 100*stdv_frequency_600days_inputAmplitude001A0/mean_frequency_600days_inputAmplitude001A0
relative_error_found_phase_annual_mod_600_CosFit_A001 = 100*stdv_phase_600days_inputAmplitude001A0/mean_phase_600days_inputAmplitude001A0

# %%
stdv_amplitude_750days_inputAmplitude001A0 = np.loadtxt("stdv_ampl_750days_yearly_inputAmplitude001A0")
stdv_frequency_750days_inputAmplitude001A0 = np.loadtxt("stdv_freq_750days_yearly_inputAmplitude001A0")
stdv_phase_750days_inputAmplitude001A0 = np.loadtxt("stdv_phase_750days_yearly_inputAmplitude001A0")

mean_amplitude_750days_inputAmplitude001A0 = np.loadtxt("mean_ampl_750days_yearly_inputAmplitude001A0")
mean_frequency_750days_inputAmplitude001A0 = np.loadtxt("mean_freq_750days_yearly_inputAmplitude001A0")
mean_phase_750days_inputAmplitude001A0 = np.loadtxt("mean_phase_750days_yearly_inputAmplitude001A0")

relative_error_found_amplitude_annual_mod_750_CosFit_A001 = 100*stdv_amplitude_750days_inputAmplitude001A0/mean_amplitude_750days_inputAmplitude001A0
relative_error_found_frequency_annual_mod_750_CosFit_A001 = 100*stdv_frequency_750days_inputAmplitude001A0/mean_frequency_750days_inputAmplitude001A0
relative_error_found_phase_annual_mod_750_CosFit_A001 = 100*stdv_phase_750days_inputAmplitude001A0/mean_phase_750days_inputAmplitude001A0

# %%
relative_stdv_amplitude_array_001A0_anMod = np.hstack((relative_error_found_amplitude_annual_mod_300_CosFit_A001, relative_error_found_amplitude_annual_mod_400_CosFit_A001, relative_error_found_amplitude_annual_mod_500_CosFit_A001, relative_error_found_amplitude_annual_mod_600_CosFit_A001, relative_error_found_amplitude_annual_mod_750_CosFit_A001))
relative_stdv_frequency_array_001A0_anMod = np.hstack((relative_error_found_frequency_annual_mod_300_CosFit_A001, relative_error_found_frequency_annual_mod_400_CosFit_A001, relative_error_found_frequency_annual_mod_500_CosFit_A001, relative_error_found_frequency_annual_mod_600_CosFit_A001, relative_error_found_frequency_annual_mod_750_CosFit_A001))
relative_stdv_phase_array_001A0_anMod = np.hstack((relative_error_found_phase_annual_mod_300_CosFit_A001, relative_error_found_phase_annual_mod_400_CosFit_A001, relative_error_found_phase_annual_mod_500_CosFit_A001, relative_error_found_phase_annual_mod_600_CosFit_A001, relative_error_found_phase_annual_mod_750_CosFit_A001))

# %%
# for input amplitude 0.2%

stdv_amplitude_300days_inputAmplitude002A0 = np.loadtxt("stdv_ampl_300days_yearly_inputAmplitude002A0")
stdv_frequency_300days_inputAmplitude002A0 = np.loadtxt("stdv_freq_300days_yearly_inputAmplitude002A0")
stdv_phase_300days_inputAmplitude002A0 = np.loadtxt("stdv_phase_300days_yearly_inputAmplitude002A0")

mean_amplitude_300days_inputAmplitude002A0 = np.loadtxt("mean_ampl_300days_yearly_inputAmplitude002A0")
mean_frequency_300days_inputAmplitude002A0 = np.loadtxt("mean_freq_300days_yearly_inputAmplitude002A0")
mean_phase_300days_inputAmplitude002A0 = np.loadtxt("mean_phase_300days_yearly_inputAmplitude002A0")

relative_error_found_amplitude_annual_mod_300_CosFit_A002 = 100*stdv_amplitude_300days_inputAmplitude002A0/mean_amplitude_300days_inputAmplitude002A0
relative_error_found_frequency_annual_mod_300_CosFit_A002 = 100*stdv_frequency_300days_inputAmplitude002A0/mean_frequency_300days_inputAmplitude002A0
relative_error_found_phase_annual_mod_300_CosFit_A002 = 100*stdv_phase_300days_inputAmplitude002A0/mean_phase_300days_inputAmplitude002A0

# %%
stdv_amplitude_400days_inputAmplitude002A0 = np.loadtxt("stdv_ampl_400days_yearly_inputAmplitude002A0")
stdv_frequency_400days_inputAmplitude002A0 = np.loadtxt("stdv_freq_400days_yearly_inputAmplitude002A0")
stdv_phase_400days_inputAmplitude002A0 = np.loadtxt("stdv_phase_400days_yearly_inputAmplitude002A0")

mean_amplitude_400days_inputAmplitude002A0 = np.loadtxt("mean_ampl_400days_yearly_inputAmplitude002A0")
mean_frequency_400days_inputAmplitude002A0 = np.loadtxt("mean_freq_400days_yearly_inputAmplitude002A0")
mean_phase_400days_inputAmplitude002A0 = np.loadtxt("mean_phase_400days_yearly_inputAmplitude002A0")

relative_error_found_amplitude_annual_mod_400_CosFit_A002 = 100*stdv_amplitude_400days_inputAmplitude002A0/mean_amplitude_400days_inputAmplitude002A0
relative_error_found_frequency_annual_mod_400_CosFit_A002 = 100*stdv_frequency_400days_inputAmplitude002A0/mean_frequency_400days_inputAmplitude002A0
relative_error_found_phase_annual_mod_400_CosFit_A002 = 100*stdv_phase_400days_inputAmplitude002A0/mean_phase_400days_inputAmplitude002A0

# %%
stdv_amplitude_500days_inputAmplitude002A0 = np.loadtxt("stdv_ampl_500days_yearly_inputAmplitude002A0")
stdv_frequency_500days_inputAmplitude002A0 = np.loadtxt("stdv_freq_500days_yearly_inputAmplitude002A0")
stdv_phase_500days_inputAmplitude002A0 = np.loadtxt("stdv_phase_500days_yearly_inputAmplitude002A0")

mean_amplitude_500days_inputAmplitude002A0 = np.loadtxt("mean_ampl_500days_yearly_inputAmplitude002A0")
mean_frequency_500days_inputAmplitude002A0 = np.loadtxt("mean_freq_500days_yearly_inputAmplitude002A0")
mean_phase_500days_inputAmplitude002A0 = np.loadtxt("mean_phase_500days_yearly_inputAmplitude002A0")

relative_error_found_amplitude_annual_mod_500_CosFit_A002 = 100*stdv_amplitude_500days_inputAmplitude002A0/mean_amplitude_500days_inputAmplitude002A0
relative_error_found_frequency_annual_mod_500_CosFit_A002 = 100*stdv_frequency_500days_inputAmplitude002A0/mean_frequency_500days_inputAmplitude002A0
relative_error_found_phase_annual_mod_500_CosFit_A002 = 100*stdv_phase_500days_inputAmplitude002A0/mean_phase_500days_inputAmplitude002A0

# %%
stdv_amplitude_600days_inputAmplitude002A0 = np.loadtxt("stdv_ampl_600days_yearly_inputAmplitude002A0")
stdv_frequency_600days_inputAmplitude002A0 = np.loadtxt("stdv_freq_600days_yearly_inputAmplitude002A0")
stdv_phase_600days_inputAmplitude002A0 = np.loadtxt("stdv_phase_600days_yearly_inputAmplitude002A0")

mean_amplitude_600days_inputAmplitude002A0 = np.loadtxt("mean_ampl_600days_yearly_inputAmplitude002A0")
mean_frequency_600days_inputAmplitude002A0 = np.loadtxt("mean_freq_600days_yearly_inputAmplitude002A0")
mean_phase_600days_inputAmplitude002A0 = np.loadtxt("mean_phase_600days_yearly_inputAmplitude002A0")

relative_error_found_amplitude_annual_mod_600_CosFit_A002 = 100*stdv_amplitude_600days_inputAmplitude002A0/mean_amplitude_600days_inputAmplitude002A0
relative_error_found_frequency_annual_mod_600_CosFit_A002 = 100*stdv_frequency_600days_inputAmplitude002A0/mean_frequency_600days_inputAmplitude002A0
relative_error_found_phase_annual_mod_600_CosFit_A002 = 100*stdv_phase_600days_inputAmplitude002A0/mean_phase_600days_inputAmplitude002A0

# %%
stdv_amplitude_750days_inputAmplitude002A0 = np.loadtxt("stdv_ampl_750days_yearly_inputAmplitude002A0")
stdv_frequency_750days_inputAmplitude002A0 = np.loadtxt("stdv_freq_750days_yearly_inputAmplitude002A0")
stdv_phase_750days_inputAmplitude002A0 = np.loadtxt("stdv_phase_750days_yearly_inputAmplitude002A0")

mean_amplitude_750days_inputAmplitude002A0 = np.loadtxt("mean_ampl_750days_yearly_inputAmplitude002A0")
mean_frequency_750days_inputAmplitude002A0 = np.loadtxt("mean_freq_750days_yearly_inputAmplitude002A0")
mean_phase_750days_inputAmplitude002A0 = np.loadtxt("mean_phase_750days_yearly_inputAmplitude002A0")

relative_error_found_amplitude_annual_mod_750_CosFit_A002 = 100*stdv_amplitude_750days_inputAmplitude002A0/mean_amplitude_750days_inputAmplitude002A0
relative_error_found_frequency_annual_mod_750_CosFit_A002 = 100*stdv_frequency_750days_inputAmplitude002A0/mean_frequency_750days_inputAmplitude002A0
relative_error_found_phase_annual_mod_750_CosFit_A002 = 100*stdv_phase_750days_inputAmplitude002A0/mean_phase_750days_inputAmplitude002A0

# %%
relative_stdv_amplitude_array_002A0_anMod = np.hstack((relative_error_found_amplitude_annual_mod_300_CosFit_A002, relative_error_found_amplitude_annual_mod_400_CosFit_A002, relative_error_found_amplitude_annual_mod_500_CosFit_A002, relative_error_found_amplitude_annual_mod_600_CosFit_A002, relative_error_found_amplitude_annual_mod_750_CosFit_A002))
relative_stdv_frequency_array_002A0_anMod = np.hstack((relative_error_found_frequency_annual_mod_300_CosFit_A002, relative_error_found_frequency_annual_mod_400_CosFit_A002, relative_error_found_frequency_annual_mod_500_CosFit_A002, relative_error_found_frequency_annual_mod_600_CosFit_A002, relative_error_found_frequency_annual_mod_750_CosFit_A002))
relative_stdv_phase_array_002A0_anMod = np.hstack((relative_error_found_phase_annual_mod_300_CosFit_A002, relative_error_found_phase_annual_mod_400_CosFit_A002, relative_error_found_phase_annual_mod_500_CosFit_A002, relative_error_found_phase_annual_mod_600_CosFit_A002, relative_error_found_phase_annual_mod_750_CosFit_A002))

# %%
# for input amplitude 0.5%

stdv_amplitude_300days_inputAmplitude005A0 = np.loadtxt("stdv_ampl_300days_yearly_inputAmplitude005A0")
stdv_frequency_300days_inputAmplitude005A0 = np.loadtxt("stdv_freq_300days_yearly_inputAmplitude005A0")
stdv_phase_300days_inputAmplitude005A0 = np.loadtxt("stdv_phase_300days_yearly_inputAmplitude005A0")

mean_amplitude_300days_inputAmplitude005A0 = np.loadtxt("mean_ampl_300days_yearly_inputAmplitude005A0")
mean_frequency_300days_inputAmplitude005A0 = np.loadtxt("mean_freq_300days_yearly_inputAmplitude005A0")
mean_phase_300days_inputAmplitude005A0 = np.loadtxt("mean_phase_300days_yearly_inputAmplitude005A0")

relative_error_found_amplitude_annual_mod_300_CosFit_A005 = 100*stdv_amplitude_300days_inputAmplitude005A0/mean_amplitude_300days_inputAmplitude005A0
relative_error_found_frequency_annual_mod_300_CosFit_A005 = 100*stdv_frequency_300days_inputAmplitude005A0/mean_frequency_300days_inputAmplitude005A0
relative_error_found_phase_annual_mod_300_CosFit_A005 = 100*stdv_phase_300days_inputAmplitude005A0/mean_phase_300days_inputAmplitude005A0

# %%
stdv_amplitude_400days_inputAmplitude005A0 = np.loadtxt("stdv_ampl_400days_yearly_inputAmplitude005A0")
stdv_frequency_400days_inputAmplitude005A0 = np.loadtxt("stdv_freq_400days_yearly_inputAmplitude005A0")
stdv_phase_400days_inputAmplitude005A0 = np.loadtxt("stdv_phase_400days_yearly_inputAmplitude005A0")

mean_amplitude_400days_inputAmplitude005A0 = np.loadtxt("mean_ampl_400days_yearly_inputAmplitude005A0")
mean_frequency_400days_inputAmplitude005A0 = np.loadtxt("mean_freq_400days_yearly_inputAmplitude005A0")
mean_phase_400days_inputAmplitude005A0 = np.loadtxt("mean_phase_400days_yearly_inputAmplitude005A0")

relative_error_found_amplitude_annual_mod_400_CosFit_A005 = 100*stdv_amplitude_400days_inputAmplitude005A0/mean_amplitude_400days_inputAmplitude005A0
relative_error_found_frequency_annual_mod_400_CosFit_A005 = 100*stdv_frequency_400days_inputAmplitude005A0/mean_frequency_400days_inputAmplitude005A0
relative_error_found_phase_annual_mod_400_CosFit_A005 = 100*stdv_phase_400days_inputAmplitude005A0/mean_phase_400days_inputAmplitude005A0

# %%
stdv_amplitude_500days_inputAmplitude005A0 = np.loadtxt("stdv_ampl_500days_yearly_inputAmplitude005A0")
stdv_frequency_500days_inputAmplitude005A0 = np.loadtxt("stdv_freq_500days_yearly_inputAmplitude005A0")
stdv_phase_500days_inputAmplitude005A0 = np.loadtxt("stdv_phase_500days_yearly_inputAmplitude005A0")

mean_amplitude_500days_inputAmplitude005A0 = np.loadtxt("mean_ampl_500days_yearly_inputAmplitude005A0")
mean_frequency_500days_inputAmplitude005A0 = np.loadtxt("mean_freq_500days_yearly_inputAmplitude005A0")
mean_phase_500days_inputAmplitude005A0 = np.loadtxt("mean_phase_500days_yearly_inputAmplitude005A0")

relative_error_found_amplitude_annual_mod_500_CosFit_A005 = 100*stdv_amplitude_500days_inputAmplitude005A0/mean_amplitude_500days_inputAmplitude005A0
relative_error_found_frequency_annual_mod_500_CosFit_A005 = 100*stdv_frequency_500days_inputAmplitude005A0/mean_frequency_500days_inputAmplitude005A0
relative_error_found_phase_annual_mod_500_CosFit_A005 = 100*stdv_phase_500days_inputAmplitude005A0/mean_phase_500days_inputAmplitude005A0

# %%
stdv_amplitude_600days_inputAmplitude005A0 = np.loadtxt("stdv_ampl_600days_yearly_inputAmplitude005A0")
stdv_frequency_600days_inputAmplitude005A0 = np.loadtxt("stdv_freq_600days_yearly_inputAmplitude005A0")
stdv_phase_600days_inputAmplitude005A0 = np.loadtxt("stdv_phase_600days_yearly_inputAmplitude005A0")

mean_amplitude_600days_inputAmplitude005A0 = np.loadtxt("mean_ampl_600days_yearly_inputAmplitude005A0")
mean_frequency_600days_inputAmplitude005A0 = np.loadtxt("mean_freq_600days_yearly_inputAmplitude005A0")
mean_phase_600days_inputAmplitude005A0 = np.loadtxt("mean_phase_600days_yearly_inputAmplitude005A0")

relative_error_found_amplitude_annual_mod_600_CosFit_A005 = 100*stdv_amplitude_600days_inputAmplitude005A0/mean_amplitude_600days_inputAmplitude005A0
relative_error_found_frequency_annual_mod_600_CosFit_A005 = 100*stdv_frequency_600days_inputAmplitude005A0/mean_frequency_600days_inputAmplitude005A0
relative_error_found_phase_annual_mod_600_CosFit_A005 = 100*stdv_phase_600days_inputAmplitude005A0/mean_phase_600days_inputAmplitude005A0

# %%
stdv_amplitude_750days_inputAmplitude005A0 = np.loadtxt("stdv_ampl_750days_yearly_inputAmplitude005A0")
stdv_frequency_750days_inputAmplitude005A0 = np.loadtxt("stdv_freq_750days_yearly_inputAmplitude005A0")
stdv_phase_750days_inputAmplitude005A0 = np.loadtxt("stdv_phase_750days_yearly_inputAmplitude005A0")

mean_amplitude_750days_inputAmplitude005A0 = np.loadtxt("mean_ampl_750days_yearly_inputAmplitude005A0")
mean_frequency_750days_inputAmplitude005A0 = np.loadtxt("mean_freq_750days_yearly_inputAmplitude005A0")
mean_phase_750days_inputAmplitude005A0 = np.loadtxt("mean_phase_750days_yearly_inputAmplitude005A0")

relative_error_found_amplitude_annual_mod_750_CosFit_A005 = 100*stdv_amplitude_750days_inputAmplitude005A0/mean_amplitude_750days_inputAmplitude005A0
relative_error_found_frequency_annual_mod_750_CosFit_A005 = 100*stdv_frequency_750days_inputAmplitude005A0/mean_frequency_750days_inputAmplitude005A0
relative_error_found_phase_annual_mod_750_CosFit_A005 = 100*stdv_phase_750days_inputAmplitude005A0/mean_phase_750days_inputAmplitude005A0

# %%
relative_stdv_amplitude_array_005A0_anMod = np.hstack((relative_error_found_amplitude_annual_mod_300_CosFit_A005, relative_error_found_amplitude_annual_mod_400_CosFit_A005, relative_error_found_amplitude_annual_mod_500_CosFit_A005, relative_error_found_amplitude_annual_mod_600_CosFit_A005, relative_error_found_amplitude_annual_mod_750_CosFit_A005))
relative_stdv_frequency_array_005A0_anMod = np.hstack((relative_error_found_frequency_annual_mod_300_CosFit_A005, relative_error_found_frequency_annual_mod_400_CosFit_A005, relative_error_found_frequency_annual_mod_500_CosFit_A005, relative_error_found_frequency_annual_mod_600_CosFit_A005, relative_error_found_frequency_annual_mod_750_CosFit_A005))
relative_stdv_phase_array_005A0_anMod = np.hstack((relative_error_found_phase_annual_mod_300_CosFit_A005, relative_error_found_phase_annual_mod_400_CosFit_A005, relative_error_found_phase_annual_mod_500_CosFit_A005, relative_error_found_phase_annual_mod_600_CosFit_A005, relative_error_found_phase_annual_mod_750_CosFit_A005))

# %%
plt.title('Input Amplitude = 0.05%')

plt.plot(measured_days_array,relative_stdv_amplitude_array_0005A0_anMod, 'r', linewidth=2., label="relative stdv amplitude")
plt.plot(measured_days_array,relative_stdv_amplitude_array_0005A0_anMod, 'ro')
plt.plot(measured_days_array,relative_stdv_phase_array_0005A0_anMod, 'b', linewidth=2., label="relative stdv phase")
plt.plot(measured_days_array,relative_stdv_phase_array_0005A0_anMod, 'bo')
plt.plot(measured_days_array,relative_stdv_frequency_array_0005A0_anMod, 'g', linewidth=2., label="relative stdv frequency")
plt.plot(measured_days_array,relative_stdv_frequency_array_0005A0_anMod, 'go')
plt.xlabel('measured days [days]')
#plt.xlim(0, 300)
plt.ylabel('relative standard deviation [%]')
plt.ylim(1.2, 1000.)
plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
# plt.savefig("rel_error_vs_measured_days_005percent_anMod.pdf", format='pdf', dpi=300)
plt.savefig("rel_error_vs_measured_days_005percent_anModPNG.png", format='png', dpi=300)
plt.show()

# %%
plt.title('Input Amplitude = 0.1%')

plt.plot(measured_days_array,relative_stdv_amplitude_array_001A0_anMod, 'r', linewidth=2., label="relative stdv amplitude")
plt.plot(measured_days_array,relative_stdv_amplitude_array_001A0_anMod, 'ro')
plt.plot(measured_days_array,relative_stdv_phase_array_001A0_anMod, 'b', linewidth=2., label="relative stdv phase")
plt.plot(measured_days_array,relative_stdv_phase_array_001A0_anMod, 'bo')
plt.plot(measured_days_array,relative_stdv_frequency_array_001A0_anMod, 'g', linewidth=2., label="relative stdv frequency")
plt.plot(measured_days_array,relative_stdv_frequency_array_001A0_anMod, 'go')
plt.xlabel('measured days [days]')
#plt.xlim(0, 300)
plt.ylabel('relative standard deviation [%]')
plt.ylim(1.2, 400.)
plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
plt.savefig("rel_error_vs_measured_days_01percent_anMod.pdf", format='pdf', dpi=300)
plt.show()

# %%
plt.title('Input Amplitude = 0.2%')

plt.plot(measured_days_array,relative_stdv_amplitude_array_002A0_anMod, 'r', linewidth=2., label="relative stdv amplitude")
plt.plot(measured_days_array,relative_stdv_amplitude_array_002A0_anMod, 'ro')
plt.plot(measured_days_array,relative_stdv_phase_array_002A0_anMod, 'b', linewidth=2., label="relative stdv phase")
plt.plot(measured_days_array,relative_stdv_phase_array_002A0_anMod, 'bo')
plt.plot(measured_days_array,relative_stdv_frequency_array_002A0_anMod, 'g', linewidth=2., label="relative stdv frequency")
plt.plot(measured_days_array,relative_stdv_frequency_array_002A0_anMod, 'go')
plt.xlabel('measured days [days]')
#plt.xlim(0, 300)
plt.ylabel('relative standard deviation [%]')
plt.ylim(0.8, 190)
plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
plt.savefig("rel_error_vs_measured_days_02percent_anMod.pdf", format='pdf', dpi=300)
plt.show()

# %%
plt.title('Input Amplitude = 0.5%')

plt.plot(measured_days_array,relative_stdv_amplitude_array_005A0_anMod, 'r', linewidth=2., label="relative stdv amplitude")
plt.plot(measured_days_array,relative_stdv_amplitude_array_005A0_anMod, 'ro')
plt.plot(measured_days_array,relative_stdv_phase_array_005A0_anMod, 'b', linewidth=2., label="relative stdv phase")
plt.plot(measured_days_array,relative_stdv_phase_array_005A0_anMod, 'bo')
plt.plot(measured_days_array,relative_stdv_frequency_array_005A0_anMod, 'g', linewidth=2., label="relative stdv frequency")
plt.plot(measured_days_array,relative_stdv_frequency_array_005A0_anMod, 'go')
plt.xlabel('measured days [days]')
#plt.xlim(0, 300)
plt.ylabel('relative standard deviation [%]')
plt.ylim(0.3, 100)
plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
plt.savefig("rel_error_vs_measured_days_05percent_anMod.pdf", format='pdf', dpi=300) 
plt.show()
